# %% [raw]
# Firearm Seizure

# %%
# imports 
import pandas as pd
from collections import defaultdict
import geopandas
# %matplotlib inline

# %%
# Read the CSV file
df = pd.read_csv('firearms.csv')
df = df.dropna()

# filter data
num_seize = df.groupby("neighborhood").sum()['total_count']
num_seize = num_seize.sort_values(ascending=False)

# %%
# normalize
scores = 10-(num_seize-3)/340*10
scores = scores.sort_values(ascending=False).rename("score")
scores
# Out:
# neighborhood
# Swisshelm Park      10.000000
# Summer Hill         10.000000
# Regent Square        9.970588
# Oakwood              9.970588
# Mt. Oliver           9.970588
#                       ...
# Carrick              5.735294
# Brighton Heights     5.705882
# Homewood North       5.411765
# South Side Flats     3.970588
# Homewood South       0.000000
# Name: score, Length: 88, dtype: float64

# %%
# dictionary: dict[neighborhood] = score
score_dict = scores.to_dict()

# %%
# plot map
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile

# do the merge
score_map = neighborhoods.merge(scores, how='left', left_on="hood", right_on='neighborhood')

# look at the head to confirm it merged correctly
score_map[['hood','score','geometry']].head()

score_map.plot(column='score', # set the data to be used for coloring
               cmap='OrRd',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Number of Firearm Seizures"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )
